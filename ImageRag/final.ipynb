# %%
# !pip install uv
# !uv pip install -r requirements.txt
# Out:
# Collecting uv
#   Downloading uv-0.7.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.7.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 68.1 MB/s eta 0:00:00
# Installing collected packages: uv
# Successfully installed uv-0.7.3
# Using Python 3.11.12 environment at: /usr
# Resolved 159 packages in 1.84s
# ⠙ Preparing packages... (0/66)
# ⠙ Preparing packages... (0/66)
# ⠙ Preparing packages... (0/66)
# ⠙ Preparing packages... (0/66)
# ⠙ Preparing packages... (0/66)
# ⠙ Preparing packages... (0/66)
# kubernetes ------------------------------ 62.91 KiB/1.90 MiB
# ⠙ Preparing packages... (0/66)
# kubernetes ------------------------------ 62.91 KiB/1.90 MiB
# ⠙ Preparing packages... (0/66)
# langchain-core ------------------------------     0 B/427.40 KiB
# kubernetes ------------------------------ 62.91 KiB/1.90 MiB
# ⠙ Preparing packages... (0/66)
# langchain-core ------------------------------ 14.88 KiB/427.40 KiB
# kubernetes ------------------------------ 62.91 KiB/1.90 MiB
# ⠙ Preparing packages... (0/66)
# opentelemetry-sdk ------------------------------     0 B/116.20 KiB
# langchain-core ------------------------------ 14.88 KiB/427.40 KiB
# kubernetes ------------------------------ 62.91 KiB/1.90 MiB
# ⠙ Preparing packages... (0/66)
# opentelemetry-sdk ------------------------------ 14.88 KiB/116.20 KiB
# langchain-core ------------------------------ 14.88 KiB/427.40 KiB
# kubernetes ------------------------------ 62.91 KiB/1.90 MiB
# ⠙ Preparing packages... (0/66)
# mmh3       ------------------------------     0 B/99.19 KiB
# opentelemetry-sdk ------------------------------ 14.88 KiB/116.20 KiB
# langchain-core ------------------------------ 14.88 KiB/427.40 KiB
# kubernetes ------------------------------ 62.91 KiB/1.90 MiB
# ⠙ Preparing packages... (0/66)
# mmh3       ------------------------------ 14.92 KiB/99.19 KiB
# opentelemetry-sdk ------------------------------ 14.88 KiB/116.20 KiB
# langchain-core ------------------------------ 14.88 KiB/427.40 KiB
# kubernetes ------------------------------ 62.91 KiB/1.90 MiB
# ⠙ Preparing packages... (0/66)
# fastapi    ------------------------------     0 B/92.93 KiB
# mmh3       ------------------------------ 14.92 KiB/99.19 KiB
# opentelemetry-sdk ------------------------------ 14.88 KiB/116.20 KiB
# langchain-core ------------------------------ 14.88 KiB/427.40 KiB
# kubernetes ------------------------------ 62.91 KiB/1.90 MiB
# ⠙ Preparing packages... (0/66)
# fastapi    ------------------------------ 14.92 KiB/92.93 KiB
# mmh3       ------------------------------ 14.92 KiB/99.19 KiB
# opentelemetry-sdk ------------------------------ 14.88 KiB/116.20 KiB
# langchain-core ------------------------------ 14.88 KiB/427.40 KiB
# kubernetes ------------------------------ 62.91 KiB/1.90 MiB
# ⠙ Preparing packages... (0/66)
# humanfriendly ------------------------------     0 B/84.76 KiB
# fastapi    ------------------------------ 14.92 KiB/92.93 KiB
# mmh3       ------------------------------ 14.92 KiB/99.19 KiB
# opentelemetry-sdk ------------------------------ 14.88 KiB/116.20 KiB
# langchain-core ------------------------------ 14.88 KiB/427.40 KiB
# kubernetes ------------------------------ 62.91 KiB/1.90 MiB
# ⠙ Preparing packages... (0/66)
# humanfriendly ------------------------------ 14.83 KiB/84.76 KiB
# fastapi    ------------------------------ 14.92 KiB/92.93 KiB
# mmh3       ------------------------------ 14.92 KiB/99.19 KiB
# opentelemetry-sdk ------------------------------ 14.88 KiB/116.20 KiB
# langchain-core ------------------------------ 14.88 KiB/427.40 KiB
# kubernetes ------------------------------ 62.91 KiB/1.90 MiB
# ⠙ Preparing packages... (0/66)
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# asgiref    ------------------------------ 14.88 KiB/23.27 KiB
# langgraph-prebuilt ------------------------------ 25.30 KiB/25.30 KiB
# importlib-metadata ------------------------------ 14.87 KiB/26.34 KiB
# dataclasses-json ------------------------------   721 B/28.01 KiB
# opentelemetry-instrumentation ------------------------------ 14.90 KiB/30.09 KiB
# langgraph-checkpoint ------------------------------ 14.88 KiB/41.32 KiB
# langchain-google-genai ------------------------------ 14.91 KiB/43.27 KiB
# pydantic-settings ------------------------------ 14.91 KiB/43.32 KiB
# coloredlogs ------------------------------ 30.83 KiB/44.94 KiB
# langgraph-sdk ------------------------------ 14.91 KiB/46.47 KiB
# marshmallow ------------------------------ 14.91 KiB/49.69 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 14.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 13.40 KiB/63.76 KiB
# starlette  ------------------------------ 14.88 KiB/70.35 KiB
# humanfriendly ------------------------------ 14.83 KiB/84.76 KiB
# posthog    ------------------------------ 30.89 KiB/89.87 KiB
# fastapi    ------------------------------ 14.92 KiB/92.93 KiB
# mmh3       ------------------------------ 78.92 KiB/99.19 KiB
# opentelemetry-sdk ------------------------------ 14.88 KiB/116.20 KiB
# ⠙ Preparing packages... (0/66)
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# asgiref    ------------------------------ 14.88 KiB/23.27 KiB
# langgraph-prebuilt ------------------------------ 25.30 KiB/25.30 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 14.04 KiB/26.69 KiB
# dataclasses-json ------------------------------ 14.88 KiB/28.01 KiB
# opentelemetry-instrumentation ------------------------------ 14.90 KiB/30.09 KiB
# langgraph-checkpoint ------------------------------ 14.88 KiB/41.32 KiB
# langchain-google-genai ------------------------------ 14.91 KiB/43.27 KiB
# pydantic-settings ------------------------------ 14.91 KiB/43.32 KiB
# coloredlogs ------------------------------ 30.83 KiB/44.94 KiB
# langgraph-sdk ------------------------------ 46.47 KiB/46.47 KiB
# marshmallow ------------------------------ 30.91 KiB/49.69 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 14.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 13.40 KiB/63.76 KiB
# starlette  ------------------------------ 14.88 KiB/70.35 KiB
# humanfriendly ------------------------------ 30.83 KiB/84.76 KiB
# posthog    ------------------------------ 30.89 KiB/89.87 KiB
# fastapi    ------------------------------ 14.92 KiB/92.93 KiB
# mmh3       ------------------------------ 94.92 KiB/99.19 KiB
# ⠙ Preparing packages... (0/66)
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# asgiref    ------------------------------ 14.88 KiB/23.27 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 14.04 KiB/26.69 KiB
# dataclasses-json ------------------------------ 14.88 KiB/28.01 KiB
# opentelemetry-instrumentation ------------------------------ 14.90 KiB/30.09 KiB
# langgraph-checkpoint ------------------------------ 30.88 KiB/41.32 KiB
# langchain-google-genai ------------------------------ 43.27 KiB/43.27 KiB
# pydantic-settings ------------------------------ 14.91 KiB/43.32 KiB
# coloredlogs ------------------------------ 44.94 KiB/44.94 KiB
# langgraph-sdk ------------------------------ 46.47 KiB/46.47 KiB
# marshmallow ------------------------------ 46.91 KiB/49.69 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 14.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 13.40 KiB/63.76 KiB
# starlette  ------------------------------ 30.38 KiB/70.35 KiB
# humanfriendly ------------------------------ 30.83 KiB/84.76 KiB
# posthog    ------------------------------ 30.89 KiB/89.87 KiB
# fastapi    ------------------------------ 14.92 KiB/92.93 KiB
# mmh3       ------------------------------ 94.92 KiB/99.19 KiB
# opentelemetry-sdk ------------------------------ 14.88 KiB/116.20 KiB
# ⠙ Preparing packages... (0/66)
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# asgiref    ------------------------------ 14.88 KiB/23.27 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 14.04 KiB/26.69 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# opentelemetry-instrumentation ------------------------------ 14.90 KiB/30.09 KiB
# langchain-google-genai ------------------------------ 43.27 KiB/43.27 KiB
# pydantic-settings ------------------------------ 43.32 KiB/43.32 KiB
# coloredlogs ------------------------------ 44.94 KiB/44.94 KiB
# langgraph-sdk ------------------------------ 46.47 KiB/46.47 KiB
# marshmallow ------------------------------ 46.91 KiB/49.69 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 14.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 13.40 KiB/63.76 KiB
# starlette  ------------------------------ 30.38 KiB/70.35 KiB
# humanfriendly ------------------------------ 30.83 KiB/84.76 KiB
# posthog    ------------------------------ 30.89 KiB/89.87 KiB
# fastapi    ------------------------------ 14.92 KiB/92.93 KiB
# mmh3       ------------------------------ 94.92 KiB/99.19 KiB
# opentelemetry-sdk ------------------------------ 14.88 KiB/116.20 KiB
# groq       ------------------------------ 30.92 KiB/124.55 KiB
# ⠙ Preparing packages... (0/66)
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# asgiref    ------------------------------ 14.88 KiB/23.27 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 14.04 KiB/26.69 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# opentelemetry-instrumentation ------------------------------ 14.90 KiB/30.09 KiB
# langchain-google-genai ------------------------------ 43.27 KiB/43.27 KiB
# pydantic-settings ------------------------------ 43.32 KiB/43.32 KiB
# coloredlogs ------------------------------ 44.94 KiB/44.94 KiB
# langgraph-sdk ------------------------------ 46.47 KiB/46.47 KiB
# marshmallow ------------------------------ 46.91 KiB/49.69 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 14.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 13.40 KiB/63.76 KiB
# starlette  ------------------------------ 30.38 KiB/70.35 KiB
# humanfriendly ------------------------------ 30.83 KiB/84.76 KiB
# posthog    ------------------------------ 30.89 KiB/89.87 KiB
# fastapi    ------------------------------ 14.92 KiB/92.93 KiB
# mmh3       ------------------------------ 94.92 KiB/99.19 KiB
# opentelemetry-sdk ------------------------------ 14.88 KiB/116.20 KiB
# groq       ------------------------------ 30.92 KiB/124.55 KiB
# ⠙ Preparing packages... (0/66)
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# asgiref    ------------------------------ 14.88 KiB/23.27 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 14.04 KiB/26.69 KiB
# opentelemetry-instrumentation ------------------------------ 14.90 KiB/30.09 KiB
# langchain-google-genai ------------------------------ 43.27 KiB/43.27 KiB
# pydantic-settings ------------------------------ 43.32 KiB/43.32 KiB
# coloredlogs ------------------------------ 44.94 KiB/44.94 KiB
# langgraph-sdk ------------------------------ 46.47 KiB/46.47 KiB
# marshmallow ------------------------------ 46.91 KiB/49.69 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 14.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 13.40 KiB/63.76 KiB
# starlette  ------------------------------ 30.38 KiB/70.35 KiB
# humanfriendly ------------------------------ 62.83 KiB/84.76 KiB
# posthog    ------------------------------ 30.89 KiB/89.87 KiB
# fastapi    ------------------------------ 30.92 KiB/92.93 KiB
# mmh3       ------------------------------ 94.92 KiB/99.19 KiB
# opentelemetry-sdk ------------------------------ 14.88 KiB/116.20 KiB
# groq       ------------------------------ 30.92 KiB/124.55 KiB
# ⠹ Preparing packages... (3/66)
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# asgiref    ------------------------------ 14.88 KiB/23.27 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 14.04 KiB/26.69 KiB
# opentelemetry-instrumentation ------------------------------ 16.61 KiB/30.09 KiB
# langchain-google-genai ------------------------------ 43.27 KiB/43.27 KiB
# pydantic-settings ------------------------------ 43.32 KiB/43.32 KiB
# coloredlogs ------------------------------ 44.94 KiB/44.94 KiB
# langgraph-sdk ------------------------------ 46.47 KiB/46.47 KiB
# marshmallow ------------------------------ 46.91 KiB/49.69 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 14.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 13.40 KiB/63.76 KiB
# starlette  ------------------------------ 30.38 KiB/70.35 KiB
# humanfriendly ------------------------------ 62.83 KiB/84.76 KiB
# posthog    ------------------------------ 30.89 KiB/89.87 KiB
# fastapi    ------------------------------ 30.92 KiB/92.93 KiB
# mmh3       ------------------------------ 99.19 KiB/99.19 KiB
# opentelemetry-sdk ------------------------------ 30.88 KiB/116.20 KiB
# groq       ------------------------------ 46.92 KiB/124.55 KiB
# ⠹ Preparing packages... (3/66)
# opentelemetry-exporter-otlp-proto-common ------------------------------     0 B/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# asgiref    ------------------------------ 14.88 KiB/23.27 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 14.04 KiB/26.69 KiB
# opentelemetry-instrumentation ------------------------------ 16.61 KiB/30.09 KiB
# langchain-google-genai ------------------------------ 43.27 KiB/43.27 KiB
# pydantic-settings ------------------------------ 43.32 KiB/43.32 KiB
# langgraph-sdk ------------------------------ 46.47 KiB/46.47 KiB
# marshmallow ------------------------------ 46.91 KiB/49.69 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 13.40 KiB/63.76 KiB
# starlette  ------------------------------ 30.38 KiB/70.35 KiB
# humanfriendly ------------------------------ 78.83 KiB/84.76 KiB
# posthog    ------------------------------ 30.89 KiB/89.87 KiB
# fastapi    ------------------------------ 30.92 KiB/92.93 KiB
# mmh3       ------------------------------ 99.19 KiB/99.19 KiB
# opentelemetry-sdk ------------------------------ 30.88 KiB/116.20 KiB
# groq       ------------------------------ 46.92 KiB/124.55 KiB
# ⠹ Preparing packages... (3/66)
# opentelemetry-exporter-otlp-proto-common ------------------------------     0 B/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# asgiref    ------------------------------ 14.88 KiB/23.27 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 14.04 KiB/26.69 KiB
# opentelemetry-instrumentation ------------------------------ 27.98 KiB/30.09 KiB
# langchain-google-genai ------------------------------ 43.27 KiB/43.27 KiB
# langgraph-sdk ------------------------------ 46.47 KiB/46.47 KiB
# marshmallow ------------------------------ 46.91 KiB/49.69 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 13.40 KiB/63.76 KiB
# starlette  ------------------------------ 30.38 KiB/70.35 KiB
# humanfriendly ------------------------------ 78.83 KiB/84.76 KiB
# posthog    ------------------------------ 30.89 KiB/89.87 KiB
# fastapi    ------------------------------ 30.92 KiB/92.93 KiB
# mmh3       ------------------------------ 99.19 KiB/99.19 KiB
# opentelemetry-sdk ------------------------------ 30.88 KiB/116.20 KiB
# groq       ------------------------------ 46.92 KiB/124.55 KiB
# ⠹ Preparing packages... (3/66)
# overrides  ------------------------------     0 B/17.41 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 16.00 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# asgiref    ------------------------------ 14.88 KiB/23.27 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 14.04 KiB/26.69 KiB
# opentelemetry-instrumentation ------------------------------ 27.98 KiB/30.09 KiB
# langchain-google-genai ------------------------------ 43.27 KiB/43.27 KiB
# langgraph-sdk ------------------------------ 46.47 KiB/46.47 KiB
# marshmallow ------------------------------ 46.91 KiB/49.69 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 13.40 KiB/63.76 KiB
# starlette  ------------------------------ 30.38 KiB/70.35 KiB
# humanfriendly ------------------------------ 78.83 KiB/84.76 KiB
# posthog    ------------------------------ 46.89 KiB/89.87 KiB
# fastapi    ------------------------------ 46.92 KiB/92.93 KiB
# opentelemetry-sdk ------------------------------ 30.88 KiB/116.20 KiB
# ⠹ Preparing packages... (3/66)
# overrides  ------------------------------     0 B/17.41 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 16.00 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# asgiref    ------------------------------ 14.88 KiB/23.27 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 14.04 KiB/26.69 KiB
# opentelemetry-instrumentation ------------------------------ 27.98 KiB/30.09 KiB
# langchain-google-genai ------------------------------ 43.27 KiB/43.27 KiB
# langgraph-sdk ------------------------------ 46.47 KiB/46.47 KiB
# marshmallow ------------------------------ 46.91 KiB/49.69 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 13.40 KiB/63.76 KiB
# starlette  ------------------------------ 30.38 KiB/70.35 KiB
# humanfriendly ------------------------------ 78.83 KiB/84.76 KiB
# posthog    ------------------------------ 46.89 KiB/89.87 KiB
# fastapi    ------------------------------ 46.92 KiB/92.93 KiB
# opentelemetry-sdk ------------------------------ 30.88 KiB/116.20 KiB
# ⠹ Preparing packages... (3/66)
# overrides  ------------------------------     0 B/17.41 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 16.00 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# asgiref    ------------------------------ 14.88 KiB/23.27 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 14.04 KiB/26.69 KiB
# opentelemetry-instrumentation ------------------------------ 27.98 KiB/30.09 KiB
# langchain-google-genai ------------------------------ 43.27 KiB/43.27 KiB
# marshmallow ------------------------------ 46.91 KiB/49.69 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 13.40 KiB/63.76 KiB
# starlette  ------------------------------ 30.38 KiB/70.35 KiB
# humanfriendly ------------------------------ 78.83 KiB/84.76 KiB
# posthog    ------------------------------ 46.89 KiB/89.87 KiB
# fastapi    ------------------------------ 46.92 KiB/92.93 KiB
# opentelemetry-sdk ------------------------------ 30.88 KiB/116.20 KiB
# groq       ------------------------------ 62.92 KiB/124.55 KiB
# ⠹ Preparing packages... (3/66)
# opentelemetry-instrumentation-asgi ------------------------------ 6.23 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 16.00 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 14.04 KiB/26.69 KiB
# opentelemetry-instrumentation ------------------------------ 27.98 KiB/30.09 KiB
# langchain-google-genai ------------------------------ 43.27 KiB/43.27 KiB
# marshmallow ------------------------------ 46.91 KiB/49.69 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 14.88 KiB/63.76 KiB
# starlette  ------------------------------ 46.38 KiB/70.35 KiB
# humanfriendly ------------------------------ 78.83 KiB/84.76 KiB
# posthog    ------------------------------ 46.89 KiB/89.87 KiB
# fastapi    ------------------------------ 46.92 KiB/92.93 KiB
# ⠹ Preparing packages... (3/66)
# langchain-groq ------------------------------ 14.07 KiB/14.90 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 16.00 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 19.78 KiB/19.78 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 26.69 KiB/26.69 KiB
# opentelemetry-instrumentation ------------------------------ 27.98 KiB/30.09 KiB
# langchain-google-genai ------------------------------ 43.27 KiB/43.27 KiB
# marshmallow ------------------------------ 49.69 KiB/49.69 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 14.88 KiB/63.76 KiB
# starlette  ------------------------------ 46.38 KiB/70.35 KiB
# humanfriendly ------------------------------ 78.83 KiB/84.76 KiB
# posthog    ------------------------------ 46.89 KiB/89.87 KiB
# ⠹ Preparing packages... (3/66)
# langchain-groq ------------------------------ 14.07 KiB/14.90 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 16.00 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 19.78 KiB/19.78 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 26.69 KiB/26.69 KiB
# opentelemetry-instrumentation ------------------------------ 27.98 KiB/30.09 KiB
# langchain-google-genai ------------------------------ 43.27 KiB/43.27 KiB
# marshmallow ------------------------------ 49.69 KiB/49.69 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 14.88 KiB/63.76 KiB
# starlette  ------------------------------ 46.38 KiB/70.35 KiB
# humanfriendly ------------------------------ 84.76 KiB/84.76 KiB
# posthog    ------------------------------ 46.89 KiB/89.87 KiB
# ⠹ Preparing packages... (3/66)
# opentelemetry-instrumentation-fastapi ------------------------------     0 B/11.84 KiB
# backoff    ------------------------------     0 B/14.79 KiB
# langchain-groq ------------------------------ 14.07 KiB/14.90 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 16.00 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 19.78 KiB/19.78 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 26.69 KiB/26.69 KiB
# opentelemetry-instrumentation ------------------------------ 27.98 KiB/30.09 KiB
# langchain-google-genai ------------------------------ 43.27 KiB/43.27 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/63.76 KiB
# starlette  ------------------------------ 46.38 KiB/70.35 KiB
# ⠹ Preparing packages... (3/66)
# opentelemetry-instrumentation-fastapi ------------------------------     0 B/11.84 KiB
# backoff    ------------------------------     0 B/14.79 KiB
# langchain-groq ------------------------------ 14.07 KiB/14.90 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 16.00 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 19.78 KiB/19.78 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 26.69 KiB/26.69 KiB
# opentelemetry-instrumentation ------------------------------ 27.98 KiB/30.09 KiB
# langchain-google-genai ------------------------------ 43.27 KiB/43.27 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/63.76 KiB
# starlette  ------------------------------ 46.38 KiB/70.35 KiB
# ⠹ Preparing packages... (3/66)
# pdf2image  ------------------------------ 11.35 KiB/11.35 KiB
# opentelemetry-instrumentation-fastapi ------------------------------ 11.84 KiB/11.84 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# langchain-groq ------------------------------ 14.07 KiB/14.90 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 16.00 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 19.78 KiB/19.78 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 26.69 KiB/26.69 KiB
# opentelemetry-instrumentation ------------------------------ 27.98 KiB/30.09 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/63.76 KiB
# starlette  ------------------------------ 46.38 KiB/70.35 KiB
# ⠹ Preparing packages... (3/66)
# pdf2image  ------------------------------ 11.35 KiB/11.35 KiB
# opentelemetry-instrumentation-fastapi ------------------------------ 11.84 KiB/11.84 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# langchain-groq ------------------------------ 14.07 KiB/14.90 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 16.00 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 19.78 KiB/19.78 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 26.69 KiB/26.69 KiB
# opentelemetry-instrumentation ------------------------------ 27.98 KiB/30.09 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/63.76 KiB
# starlette  ------------------------------ 46.38 KiB/70.35 KiB
# ⠹ Preparing packages... (3/66)
# langchain-chroma ------------------------------     0 B/11.04 KiB
# pdf2image  ------------------------------ 11.35 KiB/11.35 KiB
# opentelemetry-instrumentation-fastapi ------------------------------ 11.84 KiB/11.84 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# langchain-groq ------------------------------ 14.07 KiB/14.90 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 18.16 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# python-dotenv ------------------------------ 19.78 KiB/19.78 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 26.69 KiB/26.69 KiB
# opentelemetry-instrumentation ------------------------------ 30.09 KiB/30.09 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/63.76 KiB
# ⠹ Preparing packages... (3/66)
# langchain-chroma ------------------------------     0 B/11.04 KiB
# pdf2image  ------------------------------ 11.35 KiB/11.35 KiB
# opentelemetry-instrumentation-fastapi ------------------------------ 11.84 KiB/11.84 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# langchain-groq ------------------------------ 14.07 KiB/14.90 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 18.16 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# langchain-huggingface ------------------------------ 26.69 KiB/26.69 KiB
# opentelemetry-instrumentation ------------------------------ 30.09 KiB/30.09 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/63.76 KiB
# starlette  ------------------------------ 46.38 KiB/70.35 KiB
# ⠹ Preparing packages... (3/66)
# langchain-chroma ------------------------------     0 B/11.04 KiB
# pdf2image  ------------------------------ 11.35 KiB/11.35 KiB
# opentelemetry-instrumentation-fastapi ------------------------------ 11.84 KiB/11.84 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# langchain-groq ------------------------------ 14.07 KiB/14.90 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 18.16 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# langchain-huggingface ------------------------------ 26.69 KiB/26.69 KiB
# opentelemetry-instrumentation ------------------------------ 30.09 KiB/30.09 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/63.76 KiB
# starlette  ------------------------------ 46.38 KiB/70.35 KiB
# posthog    ------------------------------ 46.89 KiB/89.87 KiB
# ⠸ Preparing packages... (12/66)
# langchain-chroma ------------------------------     0 B/11.04 KiB
# pdf2image  ------------------------------ 11.35 KiB/11.35 KiB
# opentelemetry-instrumentation-fastapi ------------------------------ 11.84 KiB/11.84 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# langchain-groq ------------------------------ 14.07 KiB/14.90 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 18.16 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# langchain-huggingface ------------------------------ 26.69 KiB/26.69 KiB
# opentelemetry-instrumentation ------------------------------ 30.09 KiB/30.09 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/63.76 KiB
# starlette  ------------------------------ 46.38 KiB/70.35 KiB
# posthog    ------------------------------ 46.89 KiB/89.87 KiB
# ⠸ Preparing packages... (12/66)
# langchain-chroma ------------------------------     0 B/11.04 KiB
# pdf2image  ------------------------------ 11.35 KiB/11.35 KiB
# opentelemetry-instrumentation-fastapi ------------------------------ 11.84 KiB/11.84 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# langchain-groq ------------------------------ 14.07 KiB/14.90 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 18.16 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# langchain-huggingface ------------------------------ 26.69 KiB/26.69 KiB
# opentelemetry-instrumentation ------------------------------ 30.09 KiB/30.09 KiB
# opentelemetry-proto ------------------------------ 30.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/63.76 KiB
# starlette  ------------------------------ 46.38 KiB/70.35 KiB
# posthog    ------------------------------ 46.89 KiB/89.87 KiB
# ⠸ Preparing packages... (12/66)
# langchain-chroma ------------------------------ 11.04 KiB/11.04 KiB
# pdf2image  ------------------------------ 11.35 KiB/11.35 KiB
# opentelemetry-instrumentation-fastapi ------------------------------ 11.84 KiB/11.84 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# langchain-groq ------------------------------ 14.07 KiB/14.90 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 18.16 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# langchain-huggingface ------------------------------ 26.69 KiB/26.69 KiB
# opentelemetry-proto ------------------------------ 30.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/63.76 KiB
# starlette  ------------------------------ 46.38 KiB/70.35 KiB
# posthog    ------------------------------ 46.89 KiB/89.87 KiB
# fastapi    ------------------------------ 46.92 KiB/92.93 KiB
# ⠸ Preparing packages... (12/66)
# langchain-chroma ------------------------------ 11.04 KiB/11.04 KiB
# pdf2image  ------------------------------ 11.35 KiB/11.35 KiB
# opentelemetry-instrumentation-fastapi ------------------------------ 11.84 KiB/11.84 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# langchain-groq ------------------------------ 14.07 KiB/14.90 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 18.16 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# langchain-huggingface ------------------------------ 26.69 KiB/26.69 KiB
# opentelemetry-proto ------------------------------ 30.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/63.76 KiB
# starlette  ------------------------------ 46.38 KiB/70.35 KiB
# posthog    ------------------------------ 46.89 KiB/89.87 KiB
# fastapi    ------------------------------ 46.92 KiB/92.93 KiB
# opentelemetry-sdk ------------------------------ 46.88 KiB/116.20 KiB
# ⠸ Preparing packages... (12/66)
# langchain-chroma ------------------------------ 11.04 KiB/11.04 KiB
# pdf2image  ------------------------------ 11.35 KiB/11.35 KiB
# opentelemetry-instrumentation-fastapi ------------------------------ 11.84 KiB/11.84 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# langchain-groq ------------------------------ 14.07 KiB/14.90 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 14.84 KiB/19.50 KiB
# langchain-huggingface ------------------------------ 26.69 KiB/26.69 KiB
# opentelemetry-proto ------------------------------ 30.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/63.76 KiB
# starlette  ------------------------------ 46.38 KiB/70.35 KiB
# posthog    ------------------------------ 46.89 KiB/89.87 KiB
# fastapi    ------------------------------ 46.92 KiB/92.93 KiB
# opentelemetry-sdk ------------------------------ 46.88 KiB/116.20 KiB
# groq       ------------------------------ 62.92 KiB/124.55 KiB
#    Building pypika==0.48.9
# ⠸ Preparing packages... (12/66)
# opentelemetry-util-http ------------------------------     0 B/7.13 KiB
# typing-inspect ------------------------------ 8.62 KiB/8.62 KiB
# langchain-chroma ------------------------------ 11.04 KiB/11.04 KiB
# pdf2image  ------------------------------ 11.35 KiB/11.35 KiB
# opentelemetry-instrumentation-fastapi ------------------------------ 11.84 KiB/11.84 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# langchain-groq ------------------------------ 14.07 KiB/14.90 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 19.50 KiB/19.50 KiB
# langchain-huggingface ------------------------------ 26.69 KiB/26.69 KiB
# opentelemetry-proto ------------------------------ 30.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/63.76 KiB
# starlette  ------------------------------ 46.38 KiB/70.35 KiB
# posthog    ------------------------------ 46.89 KiB/89.87 KiB
# fastapi    ------------------------------ 46.92 KiB/92.93 KiB
#    Building pypika==0.48.9
# ⠸ Preparing packages... (12/66)
# opentelemetry-util-http ------------------------------     0 B/7.13 KiB
# typing-inspect ------------------------------ 8.62 KiB/8.62 KiB
# langchain-chroma ------------------------------ 11.04 KiB/11.04 KiB
# pdf2image  ------------------------------ 11.35 KiB/11.35 KiB
# opentelemetry-instrumentation-fastapi ------------------------------ 11.84 KiB/11.84 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# langchain-groq ------------------------------ 14.07 KiB/14.90 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 19.50 KiB/19.50 KiB
# langchain-huggingface ------------------------------ 26.69 KiB/26.69 KiB
# opentelemetry-proto ------------------------------ 30.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/63.76 KiB
# starlette  ------------------------------ 46.38 KiB/70.35 KiB
# posthog    ------------------------------ 46.89 KiB/89.87 KiB
# fastapi    ------------------------------ 46.92 KiB/92.93 KiB
#    Building pypika==0.48.9
# ⠸ Preparing packages... (12/66)
# opentelemetry-util-http ------------------------------     0 B/7.13 KiB
# typing-inspect ------------------------------ 8.62 KiB/8.62 KiB
# langchain-chroma ------------------------------ 11.04 KiB/11.04 KiB
# pdf2image  ------------------------------ 11.35 KiB/11.35 KiB
# opentelemetry-instrumentation-fastapi ------------------------------ 11.84 KiB/11.84 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# langchain-groq ------------------------------ 14.07 KiB/14.90 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 19.50 KiB/19.50 KiB
# langchain-huggingface ------------------------------ 26.69 KiB/26.69 KiB
# opentelemetry-proto ------------------------------ 30.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/63.76 KiB
# starlette  ------------------------------ 46.38 KiB/70.35 KiB
# posthog    ------------------------------ 46.89 KiB/89.87 KiB
# fastapi    ------------------------------ 46.92 KiB/92.93 KiB
#    Building pypika==0.48.9
# ⠸ Preparing packages... (12/66)
# opentelemetry-util-http ------------------------------     0 B/7.13 KiB
# typing-inspect ------------------------------ 8.62 KiB/8.62 KiB
# langchain-chroma ------------------------------ 11.04 KiB/11.04 KiB
# pdf2image  ------------------------------ 11.35 KiB/11.35 KiB
# opentelemetry-instrumentation-fastapi ------------------------------ 11.84 KiB/11.84 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# langchain-groq ------------------------------ 14.07 KiB/14.90 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 19.50 KiB/19.50 KiB
# langchain-huggingface ------------------------------ 26.69 KiB/26.69 KiB
# opentelemetry-proto ------------------------------ 30.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/63.76 KiB
# starlette  ------------------------------ 62.38 KiB/70.35 KiB
# posthog    ------------------------------ 46.89 KiB/89.87 KiB
# fastapi    ------------------------------ 46.92 KiB/92.93 KiB
#    Building pypika==0.48.9
# ⠸ Preparing packages... (12/66)
# opentelemetry-util-http ------------------------------     0 B/7.13 KiB
# typing-inspect ------------------------------ 8.62 KiB/8.62 KiB
# langchain-chroma ------------------------------ 11.04 KiB/11.04 KiB
# pdf2image  ------------------------------ 11.35 KiB/11.35 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# langchain-groq ------------------------------ 14.07 KiB/14.90 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# filetype   ------------------------------ 19.50 KiB/19.50 KiB
# langchain-huggingface ------------------------------ 26.69 KiB/26.69 KiB
# opentelemetry-proto ------------------------------ 30.90 KiB/54.54 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# opentelemetry-api ------------------------------ 30.88 KiB/63.76 KiB
# starlette  ------------------------------ 62.38 KiB/70.35 KiB
# posthog    ------------------------------ 46.89 KiB/89.87 KiB
# fastapi    ------------------------------ 46.92 KiB/92.93 KiB
# opentelemetry-sdk ------------------------------ 46.88 KiB/116.20 KiB
# groq       ------------------------------ 62.92 KiB/124.55 KiB
#    Building pypika==0.48.9
# ⠸ Preparing packages... (12/66)
# mypy-extensions ------------------------------ 4.85 KiB/4.85 KiB
# opentelemetry-util-http ------------------------------ 7.13 KiB/7.13 KiB
# typing-inspect ------------------------------ 8.62 KiB/8.62 KiB
# langchain-chroma ------------------------------ 11.04 KiB/11.04 KiB
# pdf2image  ------------------------------ 11.35 KiB/11.35 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# ...
# nvidia-cublas-cu12 ------------------------------ 207.90 MiB/346.60 MiB
# ⠋ Preparing packages... (62/66)
# nvidia-cublas-cu12 ------------------------------ 210.59 MiB/346.60 MiB
# ⠙ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 211.67 MiB/346.60 MiB
# ⠙ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 212.95 MiB/346.60 MiB
# ⠙ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 213.86 MiB/346.60 MiB
# ⠙ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 215.64 MiB/346.60 MiB
# ⠹ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 217.12 MiB/346.60 MiB
# ⠹ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 218.37 MiB/346.60 MiB
# ⠹ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 220.79 MiB/346.60 MiB
# ⠹ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 222.75 MiB/346.60 MiB
# ⠸ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 224.73 MiB/346.60 MiB
# ⠸ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 225.90 MiB/346.60 MiB
# ⠸ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 228.12 MiB/346.60 MiB
# ⠸ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 229.91 MiB/346.60 MiB
# ⠼ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 231.98 MiB/346.60 MiB
# ⠼ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 234.80 MiB/346.60 MiB
# ⠼ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 236.83 MiB/346.60 MiB
# ⠼ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 237.89 MiB/346.60 MiB
# ⠴ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 240.47 MiB/346.60 MiB
# ⠴ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 242.89 MiB/346.60 MiB
# ⠴ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 244.58 MiB/346.60 MiB
# ⠴ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 245.70 MiB/346.60 MiB
# ⠦ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 247.41 MiB/346.60 MiB
# ⠦ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 248.95 MiB/346.60 MiB
# ⠦ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 251.00 MiB/346.60 MiB
# ⠦ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 252.45 MiB/346.60 MiB
# ⠧ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 254.45 MiB/346.60 MiB
# ⠧ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 256.89 MiB/346.60 MiB
# ⠧ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 259.35 MiB/346.60 MiB
# ⠧ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 261.28 MiB/346.60 MiB
# ⠇ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 262.95 MiB/346.60 MiB
# ⠇ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 264.20 MiB/346.60 MiB
# ⠇ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 266.12 MiB/346.60 MiB
# ⠇ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 267.50 MiB/346.60 MiB
# ⠋ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 268.90 MiB/346.60 MiB
# ⠋ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 270.88 MiB/346.60 MiB
# ⠋ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 272.29 MiB/346.60 MiB
# ⠋ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 274.06 MiB/346.60 MiB
# ⠙ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 274.43 MiB/346.60 MiB
# ⠙ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 276.14 MiB/346.60 MiB
# ⠙ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 277.66 MiB/346.60 MiB
# ⠙ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 279.42 MiB/346.60 MiB
# ⠹ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 279.47 MiB/346.60 MiB
# ⠹ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 281.11 MiB/346.60 MiB
# ⠹ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 281.42 MiB/346.60 MiB
# ⠹ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 281.90 MiB/346.60 MiB
# ⠸ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 283.20 MiB/346.60 MiB
# ⠸ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 284.64 MiB/346.60 MiB
# ⠸ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 286.00 MiB/346.60 MiB
# ⠸ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 287.23 MiB/346.60 MiB
# ⠼ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 287.98 MiB/346.60 MiB
# ⠼ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 289.72 MiB/346.60 MiB
# ⠼ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 290.62 MiB/346.60 MiB
# ⠼ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 291.87 MiB/346.60 MiB
# ⠴ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 292.98 MiB/346.60 MiB
# ⠴ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 294.00 MiB/346.60 MiB
# ⠴ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 295.00 MiB/346.60 MiB
# ⠴ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 295.78 MiB/346.60 MiB
# ⠦ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 297.00 MiB/346.60 MiB
# ⠦ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 297.90 MiB/346.60 MiB
# ⠦ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 299.62 MiB/346.60 MiB
# ⠦ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 300.95 MiB/346.60 MiB
# ⠧ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 302.11 MiB/346.60 MiB
# ⠧ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 303.72 MiB/346.60 MiB
# ⠧ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 304.81 MiB/346.60 MiB
# ⠧ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 306.26 MiB/346.60 MiB
# ⠇ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 308.02 MiB/346.60 MiB
# ⠇ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 310.75 MiB/346.60 MiB
# ⠇ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 312.62 MiB/346.60 MiB
# ⠇ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 314.42 MiB/346.60 MiB
# ⠋ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 317.66 MiB/346.60 MiB
# ⠋ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 320.58 MiB/346.60 MiB
# ⠋ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 322.77 MiB/346.60 MiB
# ⠋ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 324.98 MiB/346.60 MiB
# ⠙ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 326.48 MiB/346.60 MiB
# ⠙ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 328.08 MiB/346.60 MiB
# ⠙ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 330.51 MiB/346.60 MiB
# ⠙ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 332.65 MiB/346.60 MiB
# ⠹ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 332.65 MiB/346.60 MiB
# ⠹ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 334.75 MiB/346.60 MiB
# ⠹ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 335.86 MiB/346.60 MiB
# ⠹ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 337.53 MiB/346.60 MiB
# ⠸ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 339.06 MiB/346.60 MiB
# ⠸ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 339.56 MiB/346.60 MiB
# ⠸ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 341.91 MiB/346.60 MiB
# ⠸ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 343.80 MiB/346.60 MiB
# ⠼ Preparing packages... (64/66)
# nvidia-cublas-cu12 ------------------------------ 345.39 MiB/346.60 MiB
# ⠼ Preparing packages... (64/66)
# ⠼ Preparing packages... (64/66)
# ⠼ Preparing packages... (64/66)
# ⠼ Preparing packages... (64/66)
# ⠴ Preparing packages... (65/66)
# ⠴ Preparing packages... (65/66)
# ⠴ Preparing packages... (65/66)
# ⠴ Preparing packages... (65/66)
# ⠦ Preparing packages... (65/66)
# ⠦ Preparing packages... (65/66)
# ⠦ Preparing packages... (65/66)
# ⠦ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠇ Preparing packages... (65/66)
# ⠇ Preparing packages... (65/66)
# ⠇ Preparing packages... (65/66)
# ⠇ Preparing packages... (65/66)
# ⠋ Preparing packages... (65/66)
# ⠋ Preparing packages... (65/66)
# ⠋ Preparing packages... (65/66)
# ⠋ Preparing packages... (65/66)
# ⠙ Preparing packages... (65/66)
# ⠙ Preparing packages... (65/66)
# ⠹ Preparing packages... (65/66)
# ⠸ Preparing packages... (65/66)
# ⠸ Preparing packages... (65/66)
# ⠸ Preparing packages... (65/66)
# ⠸ Preparing packages... (65/66)
# ⠸ Preparing packages... (65/66)
# ⠸ Preparing packages... (65/66)
# ⠼ Preparing packages... (65/66)
# ⠼ Preparing packages... (65/66)
# ⠼ Preparing packages... (65/66)
# ⠼ Preparing packages... (65/66)
# ⠼ Preparing packages... (65/66)
# ⠼ Preparing packages... (65/66)
# ⠼ Preparing packages... (65/66)
# ⠦ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠇ Preparing packages... (65/66)
# ⠋ Preparing packages... (65/66)
# ⠋ Preparing packages... (65/66)
# ⠋ Preparing packages... (65/66)
# ⠋ Preparing packages... (65/66)
# ⠋ Preparing packages... (65/66)
# ⠙ Preparing packages... (65/66)
# ⠹ Preparing packages... (65/66)
# ⠹ Preparing packages... (65/66)
# ⠹ Preparing packages... (65/66)
# ⠹ Preparing packages... (65/66)
# ⠹ Preparing packages... (65/66)
# ⠹ Preparing packages... (65/66)
# ⠹ Preparing packages... (65/66)
# ⠹ Preparing packages... (65/66)
# ⠹ Preparing packages... (65/66)
# ⠸ Preparing packages... (65/66)
# ⠼ Preparing packages... (65/66)
# ⠼ Preparing packages... (65/66)
# ⠼ Preparing packages... (65/66)
# ⠼ Preparing packages... (65/66)
# ⠼ Preparing packages... (65/66)
# ⠼ Preparing packages... (65/66)
# ⠼ Preparing packages... (65/66)
# ⠼ Preparing packages... (65/66)
# ⠴ Preparing packages... (65/66)
# ⠴ Preparing packages... (65/66)
# ⠴ Preparing packages... (65/66)
# ⠴ Preparing packages... (65/66)
# ⠦ Preparing packages... (65/66)
# ⠦ Preparing packages... (65/66)
# ⠦ Preparing packages... (65/66)
# ⠦ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠇ Preparing packages... (65/66)
# ⠇ Preparing packages... (65/66)
# ⠇ Preparing packages... (65/66)
# ⠇ Preparing packages... (65/66)
# ⠋ Preparing packages... (65/66)
# ⠋ Preparing packages... (65/66)
# ⠋ Preparing packages... (65/66)
# ⠋ Preparing packages... (65/66)
# ⠙ Preparing packages... (65/66)
# ⠙ Preparing packages... (65/66)
# ⠙ Preparing packages... (65/66)
# ⠙ Preparing packages... (65/66)
# ⠹ Preparing packages... (65/66)
# ⠹ Preparing packages... (65/66)
# ⠹ Preparing packages... (65/66)
# ⠹ Preparing packages... (65/66)
# ⠸ Preparing packages... (65/66)
# ⠸ Preparing packages... (65/66)
# ⠸ Preparing packages... (65/66)
# ⠸ Preparing packages... (65/66)
# ⠼ Preparing packages... (65/66)
# ⠼ Preparing packages... (65/66)
# ⠼ Preparing packages... (65/66)
# ⠼ Preparing packages... (65/66)
# ⠴ Preparing packages... (65/66)
# ⠴ Preparing packages... (65/66)
# ⠴ Preparing packages... (65/66)
# ⠴ Preparing packages... (65/66)
# ⠦ Preparing packages... (65/66)
# ⠦ Preparing packages... (65/66)
# ⠦ Preparing packages... (65/66)
# ⠦ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠧ Preparing packages... (65/66)
# ⠇ Preparing packages... (65/66)
# ⠇ Preparing packages... (65/66)
# ⠇ Preparing packages... (65/66)
# ⠇ Preparing packages... (65/66)
# ⠋ Preparing packages... (65/66)
# ⠋ Preparing packages... (65/66)
# ⠋ Preparing packages... (65/66)
# ⠋ Preparing packages... (65/66)
# ⠙ Preparing packages... (65/66)
# ⠙ Preparing packages... (65/66)
# ⠙ Preparing packages... (65/66)
# ⠙ Preparing packages... (65/66)
# ⠹ Preparing packages... (65/66)
# ⠹ Preparing packages... (65/66)
# ⠹ Preparing packages... (65/66)
# ⠹ Preparing packages... (65/66)
# ⠸ Preparing packages... (65/66)
# ⠸ Preparing packages... (65/66)
# Prepared 66 packages in 31.22s
# Uninstalled 16 packages in 135ms
# Installed 66 packages in 114ms
#  + asgiref==3.8.1
#  + backoff==2.2.1
#  + bcrypt==4.3.0
#  + chroma-hnswlib==0.7.6
#  + chromadb==0.6.3
#  + coloredlogs==15.0.1
#  + dataclasses-json==0.6.7
#  + dotenv==0.9.9
#  + durationpy==0.9
#  + fastapi==0.115.12
#  + filetype==1.2.0
#  - google-ai-generativelanguage==0.6.15
#  + google-ai-generativelanguage==0.6.18
#  + groq==0.24.0
#  + httptools==0.6.4
#  + httpx-sse==0.4.0
#  + humanfriendly==10.0
#  - importlib-metadata==8.7.0
#  + importlib-metadata==8.6.1
#  + kubernetes==32.0.1
#  + langchain-chroma==0.2.3
#  + langchain-community==0.3.23
#  - langchain-core==0.3.56
#  + langchain-core==0.3.59
#  + langchain-google-genai==2.1.4
#  + langchain-groq==0.3.2
#  + langchain-huggingface==0.2.0
#  + langgraph==0.4.3
#  + langgraph-checkpoint==2.0.25
#  + langgraph-prebuilt==0.1.8
#  + langgraph-sdk==0.1.66
#  + marshmallow==3.26.1
#  + mmh3==5.1.0
#  + mypy-extensions==1.1.0
#  - nvidia-cublas-cu12==12.5.3.2
#  + nvidia-cublas-cu12==12.4.5.8
#  - nvidia-cuda-cupti-cu12==12.5.82
#  + nvidia-cuda-cupti-cu12==12.4.127
#  - nvidia-cuda-nvrtc-cu12==12.5.82
#  + nvidia-cuda-nvrtc-cu12==12.4.127
#  - nvidia-cuda-runtime-cu12==12.5.82
#  + nvidia-cuda-runtime-cu12==12.4.127
#  - nvidia-cudnn-cu12==9.3.0.75
#  + nvidia-cudnn-cu12==9.1.0.70
#  - nvidia-cufft-cu12==11.2.3.61
#  + nvidia-cufft-cu12==11.2.1.3
#  - nvidia-curand-cu12==10.3.6.82
#  + nvidia-curand-cu12==10.3.5.147
#  - nvidia-cusolver-cu12==11.6.3.83
#  + nvidia-cusolver-cu12==11.6.1.9
#  - nvidia-cusparse-cu12==12.5.1.3
#  + nvidia-cusparse-cu12==12.3.1.170
#  - nvidia-nvjitlink-cu12==12.5.82
#  + nvidia-nvjitlink-cu12==12.4.127
#  + onnxruntime==1.21.1
#  - opentelemetry-api==1.16.0
#  + opentelemetry-api==1.32.1
#  + opentelemetry-exporter-otlp-proto-common==1.32.1
#  + opentelemetry-exporter-otlp-proto-grpc==1.32.1
#  + opentelemetry-instrumentation==0.53b1
#  + opentelemetry-instrumentation-asgi==0.53b1
#  + opentelemetry-instrumentation-fastapi==0.53b1
#  + opentelemetry-proto==1.32.1
#  - opentelemetry-sdk==1.16.0
#  + opentelemetry-sdk==1.32.1
#  - opentelemetry-semantic-conventions==0.37b0
#  + opentelemetry-semantic-conventions==0.53b1
#  + opentelemetry-util-http==0.53b1
#  + ormsgpack==1.9.1
#  + overrides==7.7.0
#  + pdf2image==1.17.0
#  + posthog==4.0.1
#  + pydantic-settings==2.9.1
#  + pypdf==5.4.0
#  + pypika==0.48.9
#  + python-dotenv==1.1.0
#  + starlette==0.46.2
#  + typing-inspect==0.9.0
#  + uvicorn==0.34.2
#  + uvloop==0.21.0
#  + watchfiles==1.0.5
#  + xxhash==3.5.0

# %%
from pydantic import BaseModel,Field

class State(BaseModel):
    question : str = Field(description= "Question given be the user")
    answer : str = Field(description="Answer given by the Application")
    chat_summary : str = Field(description="Chat history maintained by the applciation")

# %%
import filetype
from langchain.document_loaders import PyPDFLoader

def file_router(file):
    kind = filetype.guess(file)
    if kind is None:
        return "Unknown"
    file_type =  kind.mime
    if file_type.startswith("image/"):
        return 'imagesingle'

    # or else this is pdf and if there is images kind of pdf then return 'image' or text based then return pdf

    loader = PyPDFLoader(file)

    docs = loader.load()

    if not len(docs[0].page_content):
        return 'imagepdf'

    else :
        return 'pdf'

# %%
from langchain_chroma import Chroma

from langchain_google_genai import ChatGoogleGenerativeAI
import os
import base64
from langchain_core.messages import HumanMessage
from io import BytesIO

model = llm = ChatGoogleGenerativeAI(model = 'gemini-2.0-flash')

def encode_image(image) -> str:
    """Encode a PIL image to base64 string."""
    buffer = BytesIO()
    image.save(buffer, format="PNG")
    return base64.b64encode(buffer.getvalue()).decode("utf-8")

def image_summarize(model, base64_image: str, prompt: str) -> str:
    """Make image summary"""
    msg = model.invoke(
        [
            HumanMessage(
                content=[
                    {"type": "text", "text": prompt},
                    {
                        "type": "image_url",
                        "image_url": {"url": f"data:image/png;base64,{base64_image}"},
                    },
                ]
            )
        ]
    )
    return msg.content


image_prompt = """You are a highly meticulous AI assistant that extracts and summarizes every possible piece of visual information from an image without omitting any detail.
    Your task is to generate an exhaustive, structured summary of the image that captures all the text, visual elements, layout, colors (if relevant), numbers, figures, and any context or formatting that might be useful.
    Do not generalize or paraphrase — capture the content exactly as it appears. Use bullet points, lists, or structured sections (e.g., titles, tables, headers, footnotes) to organize your summary.

    Be especially attentive to:
    - All visible text, including headers, footnotes, and marginal notes
    - Tables: Capture each row and column verbatim including headers and cell values
    - Graphs/Charts: Explain all axes, labels, legends, data points, patterns, and conclusions
    - Visual layout and structure: Describe how content is arranged (e.g., two-column layout, centered title, left-aligned figure)
    - Icons, logos, or images embedded within the image: Describe them accurately
    - Fonts, colors, and emphasis (e.g., bold, italic, underlined) if they seem meaningful
    - Dates, numbers, symbols, or special formatting exactly as shown
    - If the image is a document or scanned page, preserve hierarchy and document structure

    Output the result in structured markdown with clear section headers (e.g., "Header", "Table 1", "Figure Description", "Text Body", "Footnotes").
    Your goal is to allow someone to fully understand the image without seeing it, preserving maximum detail for use in downstream AI models or search systems."""



def image_handler(image):

    base64_img = encode_image(image)
    summary = image_summarize(model, base64_img, prompt=image_prompt)
    with open('example.txt','w') as f:
        f.write(summary)
    return summary

# %%
def image_handler_append(image):
    base64_img = encode_image(image)
    summary = image_summarize(model, base64_img, prompt=image_prompt)

    # Append instead of overwrite
    with open('example.txt', 'a') as f:
        f.write(summary + '\n')  # Add newline for separation

    return summary

# %%
from langchain_chroma import Chroma
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings

def vectorize_text(text:str):
    splitter = RecursiveCharacterTextSplitter(chunk_size = 600,chunk_overlap = 50)

    docs = splitter.split_text(text)

    vectorstore = Chroma.from_texts(docs,embedding= HuggingFaceEmbeddings())

    return vectorstore

# %%
def vectorize_single_image(image):
    summary = image_handler(image)
    return vectorize_text(summary)

# %%
from pdf2image import convert_from_path

def vectorize_multiple_images(image):

    images = convert_from_path(image)
    summary = ''
    for i, image in enumerate(images):
        filename = f"page_{i + 1}.png"
        print(filename)
        image.save(filename, "PNG")
        if filename == 'page_1.png':
            summary = image_handler(image)
        else:
            summary += image_handler_append(image)

    return vectorize_text(summary)

# %%
from langchain.document_loaders import PyPDFLoader

def vectorize_docs(filepath):
    loader = PyPDFLoader(filepath)
    docs = loader.load()
    splitter = RecursiveCharacterTextSplitter(chunk_size= 600,chunk_overlap= 80)
    chunks = splitter.split_documents(docs)
    vectorstore = Chroma.from_documents(chunks,HuggingFaceEmbeddings())
    return vectorstore

# %%
def vectorize(filepath):
    type_of_file = file_router(filepath)
    print(type_of_file)
    if type_of_file == 'imagesingle':
        return vectorize_single_image(filepath)
    elif type_of_file == 'imagepdf':
        return vectorize_multiple_images(filepath)
    else :
        return vectorize_docs(filepath)

# %%
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain import hub
from dotenv import load_dotenv
load_dotenv()

prompt = hub.pull('rlm/rag-prompt')
from tqdm.autonotebook import tqdm as notebook_tqdm



retriever = vectorize('shreyankresume.pdf').as_retriever()

def format_docs(docs):
    return '\n\n'.join(doc.page_content for doc in docs)


rag_chain = (
    {"context":retriever |format_docs , 'question':RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)


template = """You are an AI language model assistant. Your task is to generate five
different versions of the given user question to retrieve relevant documents from a vector
database. By generating multiple perspectives on the user question, your goal is to help
the user overcome some of the limitations of the distance-based similarity search.
Provide these alternative questions separated by newlines. Original question: {question} """

from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template(template)

generate_queries = (
    prompt
    | llm
    | StrOutputParser()
    | (lambda x: x.split("\n"))
)
from langchain.load import dumps, loads

def get_unique_union(documents: list[list]):
    """ Unique union of retrieved docs """
    flattened_docs = [dumps(doc) for sublist in documents for doc in sublist]
    unique_docs = list(set(flattened_docs))
    return [loads(doc) for doc in unique_docs]


retrieval_chain = generate_queries | retriever.map() | get_unique_union



from operator import itemgetter
from langchain_core.runnables import RunnablePassthrough

template = """Answer the following question based on this context:

{context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)



final_rag_chain = (
    {"context": retrieval_chain,
     "question": itemgetter("question")}
    | prompt
    | llm
    | StrOutputParser()
)
# Out:
# /usr/local/lib/python3.11/dist-packages/langsmith/client.py:272: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(
# <ipython-input-16-221112746ad3>:8: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm as notebook_tqdm
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-221112746ad3> in <cell line: 0>()
#      10
#      11
# ---> 12 retriever = vectorize('shreyankresume.pdf').as_retriever()
#      13
#      14 def format_docs(docs):
#
# <ipython-input-15-db7c486a9837> in vectorize(filepath)
#       1 def vectorize(filepath):
# ----> 2     type_of_file = file_router(filepath)
#       3     print(type_of_file)
#       4     if type_of_file == 'imagesingle':
#       5         return vectorize_single_image(filepath)
#
# <ipython-input-7-2d84fb8a54ed> in file_router(file)
#       3
#       4 def file_router(file):
# ----> 5     kind = filetype.guess(file)
#       6     if kind is None:
#       7         return "Unknown"
#
# /usr/local/lib/python3.11/dist-packages/filetype/filetype.py in guess(obj)
#      26         TypeError: if obj is not a supported type.
#      27     """
# ---> 28     return match(obj) if obj else None
#      29
#      30
#
# /usr/local/lib/python3.11/dist-packages/filetype/match.py in match(obj, matchers)
#      28         TypeError: if obj is not a supported type.
#      29     """
# ---> 30     buf = get_bytes(obj)
#      31
#      32     for matcher in matchers:
#
# /usr/local/lib/python3.11/dist-packages/filetype/utils.py in get_bytes(obj)
#      62
#      63     if isinstance(obj, str):
# ---> 64         return get_signature_bytes(obj)
#      65
#      66     if isinstance(obj, bytes):
#
# /usr/local/lib/python3.11/dist-packages/filetype/utils.py in get_signature_bytes(path)
#      22         First 8192 bytes of the file content as bytearray type.
#      23     """
# ---> 24     with open(path, 'rb') as fp:
#      25         return bytearray(fp.read(_NUM_SIGNATURE_BYTES))
#      26
#
# FileNotFoundError: [Errno 2] No such file or directory: 'shreyankresume.pdf'

# %%
#print(result)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableMap, RunnablePassthrough


fallback_prompt = """
You are a helpful and honest assistant working within a RAG (Retrieval-Augmented Generation) system. You attempted to answer a user's question based on retrieved knowledge, but the information may be incomplete, irrelevant, or not confidently grounded.

Your goal now is to:
- Review the chat summary to understand ongoing conversation context.
- Review the retrieved context.
- Evaluate the initially attempted answer.
- If the context was insufficient or the answer is vague, provide a polite, thoughtful fallback response.
- If helpful, ask the user to clarify or reformulate their question.

---

Chat Summary (Conversation So Far):
{chat_summary}

User Question:
{question}

Initial Answer Attempted:
{answer}

---

Just return 'fall_back' if the answer is NOT good enough.
Return 'continue' if the answer is relevant and sufficient.
"""


fall_back_prompt = ChatPromptTemplate.from_template(fallback_prompt)

def fallback_node(state: State) -> dict:
    chat_summary = state.chat_summary
    question = state.question
    answer = state.answer

    # Combine into a runnable chain
    fallback_chain = fall_back_prompt | llm | StrOutputParser()

    # Provide input variables to the chain
    decision = fallback_chain.invoke({
        "chat_summary": chat_summary,
        "question": question,
        "answer": answer
    })

    decision = decision.strip().lower()

    if decision == "continue":
        return {"answer": answer}
    else:
        fallback_response = (
            "Apologies! It seems I don't have enough reliable information to confidently answer your question right now. "
            "This might be due to insufficient or unclear context. "
            "Please consider rephrasing your question or using a more advanced model for better results."
        )
        return {"answer": fallback_response}

# %%
summarizer_prompt = """
You are an expert summarizer. Summarize the entire conversation, including the latest question and answer pair, while preserving the key points.

Previous Summary ignore if its not there:
{previous_summary}

New Question and Answer:
Question: {question}
Answer: {answer}

---

Updated Summary:
"""

import dotenv
dotenv.load_dotenv()

from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model = 'gemini-1.5-flash')

def summarizer_node(state:State):

    question = state.question
    answer = state.answer
    previous_summary = state.chat_summary


    prompt = summarizer_prompt.format(
        previous_summary=previous_summary,
        question=question,
        answer=answer
    )


    updated_summary = llm.invoke(prompt)


    return {"updated_summary": updated_summary}

# %%
from typing import Literal
from langchain_core.runnables import RunnableParallel


class HallucinationGrader(BaseModel):
    "Binary score for hallucination check in llm's response"

    grade: Literal["yes", "no"] = Field(
        ..., description="'yes' if the llm's reponse is hallucinated otherwise 'no'"
    )

# %%
hallucination_grader_system_prompt_template = (
    '''You are a grader assessing whether a response from an LLM is grounded in the given question and the context provided during the retrieval process.
    You will be given the following inputs:
    - The question asked by the user is {question}

    - The answer provided by the RAG application is on the basis of the context is
    {answer}


    Your task is to determine if the LLM's response is based on the context (implicitly retrieved).
    If the LLM's response does not align with the question or context (introduces unrelated information),
    it is considered a hallucination. In such cases, give a score of 'yes' (hallucinated).
    If the LLM's response is grounded in the context and consistent with the question, give a score of 'no' (not hallucinated).

    Just provide your answer in the following JSON format:
     grade: yes  or  grade: no
    No additional explanation is needed.'''


)

hallucination_grader_prompt = ChatPromptTemplate.from_template(hallucination_grader_system_prompt_template)

# %%
def hallucination_grader(state: State):
    hallucination_grader_chain = (
        hallucination_grader_prompt
        | llm.with_structured_output(HallucinationGrader, method="json_mode")
    )


    graded_response = hallucination_grader_chain.invoke({
        'question': state.question,
        'answer': state.answer
    })

    return graded_response

# %%
class AnswerGrader(BaseModel):
    '''Binary score for an answer check based on a query.'''

    grade: Literal["yes", "no"] = Field(
        description="'yes' if the provided answer is an actual answer to the query otherwise 'no',"
    )


answer_grader_system_prompt_template = (
    '''
    You are a grader assessing whether the provided answer is a valid and relevant response to the given query.
    If the provided answer addresses the query correctly, give a score of 'yes'.
    If the provided answer does not answer the query or is irrelevant, give a score of 'no'.
    Just provide your answer in the following JSON format:
    grade: yes or grade: no
    No additional explanation is needed.'''
)

# %%
answer_grader_prompt = ChatPromptTemplate.from_template(answer_grader_system_prompt_template)
answer_grader_chain = answer_grader_prompt | llm.with_structured_output(
        AnswerGrader, method="json_mode"
    )


def answer_grader(state:State):
    answer = state.answer
    question = state.question
    grade = answer_grader_chain.invoke({'question':question,'answer':answer})
    return grade

# %%
def hallucination_and_answer_relevance_check(state:State):


    hallucination_grade = hallucination_grader(state)
    print(f"hallucinatio grade is {hallucination_grade}")
    if hallucination_grade.grade == "no":
        print("---Hallucination check passed---")
        answer_relevance_grade = answer_grader(state)
        print(answer_relevance_grade)
        if answer_relevance_grade.grade == "yes":
            print("---Answer is relevant to question---\n")
            return "useful"
        else:
            print("---Answer is not relevant to question---")
            return "not_useful"
    print("---Hallucination check failed---")
    return "generate"

# %%
def rag_answer(state:State):
    query = state.question
    answer = final_rag_chain.invoke({'question':query})
    return {'answer':answer}

# %%
from langgraph.graph import StateGraph, START, END

builder = StateGraph(State)

# Add your nodes
builder.add_node("rag_answer", rag_answer)
builder.add_node("summarizer_node", summarizer_node)
# Remove this line - it's confusing the graph
# builder.add_node("hallucination_and_answer_relevance_check", hallucination_and_answer_relevance_check)
builder.add_node("fallback_node", fallback_node)

# Define your edges
builder.add_edge(START, "rag_answer")
builder.add_edge("rag_answer", "summarizer_node")

# Add conditional edge using the function as a router, not as a node
builder.add_conditional_edges(
    "summarizer_node",
    hallucination_and_answer_relevance_check,
   {
        "useful": END,
        "generate": "rag_answer",
        "not_useful": "fallback_node"
    },
)
builder.add_edge("fallback_node", END)

app = builder.compile()

# %%
app.get

# %%
state = State(question = "What job role is perfect for the candidiate",answer = '',chat_summary = '')

# %%
graph.invoke(state)

# %%
print(graph.get_graph().draw_ascii())
